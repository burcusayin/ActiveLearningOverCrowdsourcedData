# %% [markdown]
# ## EXPERIMENTS - Scenario 1
#
#
# ### Recognizing Textual Entailment Dataset

# %%
import sys
sys.path.append('./Classes/')
from results import Results

# %%
results = {}
resplot = Results()
resplot.readResult('rte_combined')
result = resplot.printResults()
results['rte_combined'] = result

# %% [markdown]
# ### Emotion - Anger

# %%
resplot = Results() 
resplot.readResult('emotion_combined')
result = resplot.printResults()
results['emotion_combined'] = result

# %% [markdown]
# ### Amazon Sentiment Dataset - "Does this abstract belongs to a book?" predicate

# %%
resplot = Results() 
resplot.readResult('amazon_isBook_combined')
result = resplot.printResults()
results['amazon_isBook_combined'] = result

# %% [markdown]
# ### Amazon Sentiment Dataset - "Does this abstract have a negative sentiment?" predicate

# %%
resplot = Results()  
resplot.readResult('amazon_isNegative_combined')
result = resplot.printResults()
results['amazon_isNegative_combined'] = result

# %% [markdown]
# ### Crisis: Practical Extraction of Disaster-Relevant Information from Social Media Dataset - "The author of the tweet seems to be an eye witness of the event?" predicate

# %%
resplot = Results() 
resplot.readResult('crisis_author_combined')
result = resplot.printResults()
results['crisis_author_combined'] = result

# %% [markdown]
# ### Crisis: Practical Extraction of Disaster-Relevant Information from Social Media Dataset - "What is the type of the message?" predicate

# %%
resplot = Results() 
resplot.readResult('crisis_message_combined')
result = resplot.printResults()
results['crisis_message_combined'] = result

# %% [markdown]
# ### Crisis: Practical Extraction of Disaster-Relevant Information from Social Media - Determine The Type Of A Hurricane-Related Tweet Dataset

# %%
resplot = Results()
resplot.readResult('crisis_type_combined')
result = resplot.printResults()
results['crisis_type_combined'] = result

# %% [markdown]
# ### Exergame

# %%
resplot = Results()
resplot.readResult('exergame_combined')
result = resplot.printResults()
results['exergame_combined'] = result

# %% [markdown]
# ## Create result files

# %%
print(results)
import xlsxwriter 
workbook = xlsxwriter.Workbook('results_scenario1.xlsx')  
#datasets = ['rte_combined', 'emotion_combined', 'amazon_isBook_combined', 'amazon_isNegative_combined', 'crisis_author_combined', 'crisis_message_combined', 'crisis_type_combined']
datasets = ['rte_combined', 'emotion_combined', 'amazon_isBook_combined', 'amazon_isNegative_combined', 'crisis_author_combined', 'crisis_message_combined', 'crisis_type_combined', 'exergame_combined']
algos = ['random', 'uncertainty', 'certainty', 'block-certainty-1', 'quire', 'lal-rand', 'lal-iter', 'minExpError']

wsAcc = workbook.add_worksheet("accuracy")
row = 0
col = 0

for algo in algos:
    row +=1
    wsAcc.write(row, col, algo)

row = 0
for dataset in datasets:
    col +=2
    wsAcc.write(row, col, dataset)

row = 1
col = 1

for algo in algos: 
    for dataset in datasets:
        # write operation perform 
        if algo not in results[dataset]:
            wsAcc.write(row, col, None)
            col +=1
            wsAcc.write(row, col, None)
            col +=1
        else:
            wsAcc.write(row, col, round(results[dataset][algo]['accuracy1'], 3)) 
            col +=1
            wsAcc.write(row, col, round(results[dataset][algo]['accuracy2'], 3)) 
            col +=1
    row += 1
    col = 1

wsF1 = workbook.add_worksheet("F1")
row = 0
col = 0

for algo in algos:
    row +=1
    wsF1.write(row, col, algo)

row = 0
for dataset in datasets:
    col +=2
    wsF1.write(row, col, dataset)

row = 1
col = 1

for algo in algos: 
    for dataset in datasets:
        # write operation perform 
        if algo not in results[dataset]:
            wsF1.write(row, col, None)
            col +=1
            wsF1.write(row, col, None)
            col +=1
        else:
            wsF1.write(row, col, round(results[dataset][algo]['fbeta11'], 3)) 
            col +=1
            wsF1.write(row, col, round(results[dataset][algo]['fbeta12'], 3)) 
            col +=1
    row += 1
    col = 1
    
wsF3 = workbook.add_worksheet("F3")
row = 0
col = 0

for algo in algos:
    row +=1
    wsF3.write(row, col, algo)

row = 0
for dataset in datasets:
    col +=2
    wsF3.write(row, col, dataset)

row = 1
col = 1

for algo in algos: 
    for dataset in datasets:
        # write operation perform 
        if algo not in results[dataset]:
            wsF3.write(row, col, None)
            col +=1
            wsF3.write(row, col, None)
            col +=1
        else:
            wsF3.write(row, col, round(results[dataset][algo]['fbeta31'], 3)) 
            col +=1
            wsF3.write(row, col, round(results[dataset][algo]['fbeta31'], 3)) 
            col +=1
    row += 1
    col = 1
    
# Cost (K= 100)
algos = ['random', 'uncertainty', 'certainty', 'block-certainty-100', 'quire', 'lal-rand', 'lal-iter', 'minExpError']
wsC100 = workbook.add_worksheet("Cost (K=100)")
row = 0
col = 0

for algo in algos:
    row +=1
    wsC100.write(row, col, algo)

row = 0
for dataset in datasets:
    col +=2
    wsC100.write(row, col, dataset)
row = 1
col = 1

for algo in algos: 
    for dataset in datasets:
        # write operation perform 
        if algo not in results[dataset]:
            wsC100.write(row, col, None)
            col +=1
            wsC100.write(row, col, None)
            col +=1
        else:
            wsC100.write(row, col, round(results[dataset][algo]['cost1_100'], 3)) 
            col +=1
            wsC100.write(row, col, round(results[dataset][algo]['cost1_100'], 3)) 
            col +=1
    row += 1
    col = 1

# Cost (K= 10)
algos = ['random', 'uncertainty', 'certainty', 'block-certainty-10', 'quire', 'lal-rand', 'lal-iter', 'minExpError']
wsC10 = workbook.add_worksheet("Cost (K=10)")
row = 0
col = 0

for algo in algos:
    row +=1
    wsC10.write(row, col, algo)

row = 0
for dataset in datasets:
    col +=2
    wsC10.write(row, col, dataset)

row = 1
col = 1

for algo in algos: 
    for dataset in datasets:
        # write operation perform 
        if algo not in results[dataset]:
            wsC10.write(row, col, None)
            col +=1
            wsC10.write(row, col, None)
            col +=1
        else:
            wsC10.write(row, col, round(results[dataset][algo]['cost1_10'], 3)) 
            col +=1
            wsC10.write(row, col, round(results[dataset][algo]['cost1_10'], 3)) 
            col +=1
    row += 1
    col = 1
    
# Cost (K= 1)
algos = ['random', 'uncertainty', 'certainty', 'block-certainty-1', 'quire', 'lal-rand', 'lal-iter', 'minExpError']
wsC1 = workbook.add_worksheet("Cost (K=1)")
row = 0
col = 0

for algo in algos:
    row +=1
    wsC1.write(row, col, algo)

row = 0
for dataset in datasets:
    col +=2
    wsC1.write(row, col, dataset)

row = 1
col = 1

for algo in algos: 
    for dataset in datasets:
        # write operation perform 
        if algo not in results[dataset]:
            wsC1.write(row, col, None)
            col +=1
            wsC1.write(row, col, None)
            col +=1
        else:
            wsC1.write(row, col, round(results[dataset][algo]['cost1_1'], 3)) 
            col +=1
            wsC1.write(row, col, round(results[dataset][algo]['cost1_1'], 3)) 
            col +=1
    row += 1
    col = 1
    
# Cost (K= 0.1)
algos = ['random', 'uncertainty', 'certainty', 'block-certainty-01', 'quire', 'lal-rand', 'lal-iter', 'minExpError']
wsC01 = workbook.add_worksheet("Cost (K=0.1)")
row = 0
col = 0

for algo in algos:
    row +=1
    wsC01.write(row, col, algo)

row = 0
for dataset in datasets:
    col +=2
    wsC01.write(row, col, dataset)

row = 1
col = 1

for algo in algos: 
    for dataset in datasets:
        # write operation perform 
        if algo not in results[dataset]:
            wsC01.write(row, col, None)
            col +=1
            wsC01.write(row, col, None)
            col +=1
        else:
            wsC01.write(row, col, round(results[dataset][algo]['cost1_0.1'], 3)) 
            col +=1
            wsC01.write(row, col, round(results[dataset][algo]['cost1_0.1'], 3)) 
            col +=1
    row += 1
    col = 1
    
# Cost (K= 0.01)
algos = ['random', 'uncertainty', 'certainty', 'block-certainty-001', 'quire', 'lal-rand', 'lal-iter', 'minExpError']
wsC001 = workbook.add_worksheet("Cost (K=0.01)")
row = 0
col = 0

for algo in algos:
    row +=1
    wsC001.write(row, col, algo)

row = 0
for dataset in datasets:
    col +=2
    wsC001.write(row, col, dataset)

row = 1
col = 1

for algo in algos: 
    for dataset in datasets:
        # write operation perform 
        if algo not in results[dataset]:
            wsC001.write(row, col, None)
            col +=1
            wsC001.write(row, col, None)
            col +=1
        else:
            wsC001.write(row, col, round(results[dataset][algo]['cost1_0.01'], 3)) 
            col +=1
            wsC001.write(row, col, round(results[dataset][algo]['cost1_0.01'], 3)) 
            col +=1
    row += 1
    col = 1
    
# num of classified items
algos = ['random', 'uncertainty', 'certainty', 'block-certainty-1', 'quire', 'lal-rand', 'lal-iter', 'minExpError']
wsClf = workbook.add_worksheet("#OfClfITems")
row = 0
col = 0

for algo in algos:
    row +=1
    wsClf.write(row, col, algo)
row = 0    
for dataset in datasets:
    col +=1
    wsClf.write(row, col, dataset)

row = 1
col = 1

for algo in algos: 
    for dataset in datasets:
        # write operation perform 
        if algo not in results[dataset]:
            wsClf.write(row, col, None)
            col +=1
        else:
            wsClf.write(row, col, round(results[dataset][algo]['numOfTrainedItems'], 3)) 
            col +=1
    row += 1
    col = 1

workbook.close()
# Out:
# {'rte_combined': {'random': {'accuracy1': 0.6409374999999999, 'accuracy2': 0.6619375000000001, 'fbeta11': 0.6629274399372067, 'fbeta12': 0.6843883560265547, 'fbeta31': 0.6980038333526293, 'fbeta32': 0.7232511204571997, 'cost1_100': 593.265, 'cost2_100': 540.45, 'cost1_10': 66.99, 'cost2_10': 61.425, 'cost1_1': 14.3625, 'cost2_1': 13.522499999999999, 'cost1_0.1': 9.09975, 'cost2_0.1': 8.73225, 'cost1_0.01': 8.573475, 'cost2_0.01': 8.253225, 'numOfTrainedItems': 520.25}, 'uncertainty': {'accuracy1': 0.663875, 'accuracy2': 0.688375, 'fbeta11': 0.6969185784788219, 'fbeta12': 0.7208410088741011, 'fbeta31': 0.7578677655156005, 'fbeta32': 0.7865296210972218, 'cost1_100': 457.95500000000004, 'cost2_100': 397.575, 'cost1_10': 53.855, 'cost2_10': 47.475, 'cost1_1': 13.444999999999999, 'cost2_1': 12.465, 'cost1_0.1': 9.404, 'cost2_0.1': 8.964, 'cost1_0.01': 8.9999, 'cost2_0.01': 8.6139, 'numOfTrainedItems': 634.9}, 'certainty': {'accuracy1': 0.56375, 'accuracy2': 0.576, 'fbeta11': 0.5540922253064683, 'fbeta12': 0.5670765125754458, 'fbeta31': 0.5600774036551337, 'fbeta32': 0.572314246393342, 'cost1_100': 881.4725000000001, 'cost2_100': 857.2225000000001, 'cost1_10': 95.9975, 'cost2_10': 93.3475